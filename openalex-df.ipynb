# %%
import requests
import pandas as pd

def write_dataframe_to_csv(df, filename):

# Write DataFrame to CSV file
    df.to_csv(filename, index=False)
    print(f"DataFrame successfully written to {filename}")


# Make the API request
url = "https://api.openalex.org/works?filter=institutions.country_code:de,institutions.country_code:ua"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Get the JSON data from the response
    data = response.json()

    # Extract the items from the JSON data
    items = data.get('results', [])

    # Create a DataFrame from the items
    df = pd.DataFrame(items)
    print(df.head())  # Print the first few rows of the DataFrame
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
#                                  id  \
# 0  https://openalex.org/W2101234009
# 1  https://openalex.org/W2124058583
# 2  https://openalex.org/W2161411308
# 3  https://openalex.org/W2134142320
# 4  https://openalex.org/W2144790402
#
#                                              doi  \
# 0                                           None
# 1      https://doi.org/10.1192/bjp.bp.107.040113
# 2        https://doi.org/10.1126/science.1197754
# 3       https://doi.org/10.1200/jco.2010.33.5091
# 4  https://doi.org/10.1016/s1470-2045(14)71159-3
#
#                                                title  \
# 0           Scikit-learn: Machine Learning in Python
# 1  Cross-national prevalence and risk factors for...
# 2  Differences Between Tight and Loose Cultures: ...
# 3  Cetuximab Plus Irinotecan, Fluorouracil, and L...
# 4  The cyclin-dependent kinase 4/6 inhibitor palb...
#
#                                         display_name  publication_year  \
# 0           Scikit-learn: Machine Learning in Python              2011
# 1  Cross-national prevalence and risk factors for...              2008
# 2  Differences Between Tight and Loose Cultures: ...              2011
# 3  Cetuximab Plus Irinotecan, Fluorouracil, and L...              2011
# 4  The cyclin-dependent kinase 4/6 inhibitor palb...              2015
#
#   publication_date                                                ids  \
# 0       2011-10-12  {'openalex': 'https://openalex.org/W2101234009...
# 1       2008-02-01  {'openalex': 'https://openalex.org/W2124058583...
# 2       2011-05-27  {'openalex': 'https://openalex.org/W2161411308...
# 3       2011-05-20  {'openalex': 'https://openalex.org/W2134142320...
# 4       2015-01-01  {'openalex': 'https://openalex.org/W2144790402...
#
#   language                                   primary_location  \
# 0       en  {'is_oa': True, 'landing_page_url': 'https://h...
# 1       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 2       en  {'is_oa': False, 'landing_page_url': 'https://...
# 3       en  {'is_oa': True, 'landing_page_url': 'https://d...
# 4       en  {'is_oa': False, 'landing_page_url': 'https://...
#
#               type  ...                                   best_oa_location  \
# 0  journal-article  ...  {'is_oa': True, 'landing_page_url': 'https://h...
# 1  journal-article  ...  {'is_oa': True, 'landing_page_url': 'https://d...
# 2  journal-article  ...  {'is_oa': True, 'landing_page_url': 'https://h...
# 3  journal-article  ...  {'is_oa': True, 'landing_page_url': 'https://d...
# 4  journal-article  ...                                               None
#
#                                               grants  \
# 0                                                 []
# 1                                                 []
# 2  [{'funder': 'https://openalex.org/F4320306076'...
# 3                                                 []
# 4                                                 []
#
#                                     referenced_works  \
# 0  [https://openalex.org/W1496508106, https://ope...
# 1  [https://openalex.org/W1979898660, https://ope...
# 2  [https://openalex.org/W959443338, https://open...
# 3  [https://openalex.org/W1969730641, https://ope...
# 4  [https://openalex.org/W1966714873, https://ope...
#
#                                        related_works  \
# 0  [https://openalex.org/W1974832135, https://ope...
# 1  [https://openalex.org/W1976379773, https://ope...
# 2  [https://openalex.org/W1520019794, https://ope...
# 3  [https://openalex.org/W2071471252, https://ope...
# 4  [https://openalex.org/W2144790402, https://ope...
#
#                                           ngrams_url  \
# 0  https://api.openalex.org/works/W2101234009/ngrams
# 1  https://api.openalex.org/works/W2124058583/ngrams
# 2  https://api.openalex.org/works/W2161411308/ngrams
# 3  https://api.openalex.org/works/W2134142320/ngrams
# 4  https://api.openalex.org/works/W2144790402/ngrams
#
#                              abstract_inverted_index  \
# 0  {'Scikit-learn': [0], 'is': [1, 35, 51], 'a': ...
# 1  {'Background': [0], 'Suicide': [1], 'is': [2, ...
# 2  {'The': [0], 'differences': [1], 'across': [2]...
# 3  {'Purpose': [0], 'The': [1, 105, 128, 231], 'a...
# 4  {'<h2>Summary</h2><h3>Background</h3>': [0], '...
#
#                                     cited_by_api_url  \
# 0  https://api.openalex.org/works?filter=cites:W2...
# 1  https://api.openalex.org/works?filter=cites:W2...
# 2  https://api.openalex.org/works?filter=cites:W2...
# 3  https://api.openalex.org/works?filter=cites:W2...
# 4  https://api.openalex.org/works?filter=cites:W2...
#
#                                       counts_by_year  \
# 0  [{'year': 2023, 'cited_by_count': 4}, {'year':...
# 1  [{'year': 2023, 'cited_by_count': 87}, {'year'...
# 2  [{'year': 2023, 'cited_by_count': 104}, {'year...
# 3  [{'year': 2023, 'cited_by_count': 42}, {'year'...
# 4  [{'year': 2023, 'cited_by_count': 46}, {'year'...
#
#                  updated_date  created_date
# 0  2023-06-04T14:53:19.844043    2016-06-24
# 1  2023-06-10T17:38:32.267804    2016-06-24
# 2  2023-06-08T12:01:30.902726    2016-06-24
# 3  2023-06-12T21:56:45.594557    2016-06-24
# 4  2023-06-10T05:24:44.162001    2016-06-24
#
# [5 rows x 34 columns]
